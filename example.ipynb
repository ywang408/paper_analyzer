# %%
import paper_analyzer as pa
import paper_analyzer.utils as utils
import re

search = pa.Search(query="all:electron", start=0, max_results=10)

for paper in search.results():
    print(paper)
    print("")
# Out:
# title: Impact of Electron-Electron Cusp on Configuration Interaction Energies
# authors: ['David Prendergast', 'M. Nolan', 'Claudia Filippi', 'Stephen Fahy', 'J. C. Greer']
# link: http://arxiv.org/abs/cond-mat/0102536v1
# doi: 10.1063/1.1383585
# pdf_link: http://arxiv.org/pdf/cond-mat/0102536v1
# term: cond-mat.str-el
#
#
# title: Electron thermal conductivity owing to collisions between degenerate
#   electrons
# authors: ['P. S. Shternin', 'D. G. Yakovlev']
# link: http://arxiv.org/abs/astro-ph/0608371v1
# doi: 10.1103/PhysRevD.74.043004
# pdf_link: http://arxiv.org/pdf/astro-ph/0608371v1
# term: astro-ph
#
#
# title: Electron pairing: from metastable electron pair to bipolaron
# authors: ['Guo-Qiang Hai', 'Ladir Cândido', 'Braulio G. A. Brito', 'François M. Peeters']
# link: http://arxiv.org/abs/1802.06593v1
# doi: 10.1088/2399-6528/aaaee0
# pdf_link: http://arxiv.org/pdf/1802.06593v1
# term: cond-mat.str-el
#
#
# ...

# %%
df = search.to_dataframe()
df
# Out:
#                                   paper_id                   updated
# 0  http://arxiv.org/abs/cond-mat/0102536v1 2001-02-28 20:12:09+00:00  \
# 1  http://arxiv.org/abs/astro-ph/0608371v1 2006-08-17 14:05:46+00:00
# 2        http://arxiv.org/abs/1802.06593v1 2018-02-19 11:51:42+00:00
# 3        http://arxiv.org/abs/2010.01066v1 2020-10-02 15:46:56+00:00
# 4        http://arxiv.org/abs/1501.04914v1 2015-01-20 18:48:22+00:00
# 5         http://arxiv.org/abs/0707.4225v1 2007-07-28 09:32:22+00:00
# 6  http://arxiv.org/abs/astro-ph/9904306v1 1999-04-22 15:54:59+00:00
# 7  http://arxiv.org/abs/cond-mat/0310615v1 2003-10-27 08:59:02+00:00
# 8        http://arxiv.org/abs/2101.10508v1 2021-01-26 01:15:10+00:00
# 9  http://arxiv.org/abs/cond-mat/0205001v1 2002-04-30 20:00:18+00:00
#
#                   published
# 0 2001-02-28 20:12:09+00:00  \
# 1 2006-08-17 14:05:46+00:00
# 2 2018-02-19 11:51:42+00:00
# 3 2020-10-02 15:46:56+00:00
# 4 2015-01-20 18:48:22+00:00
# 5 2007-07-28 09:32:22+00:00
# ...
